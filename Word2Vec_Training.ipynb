# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data.csv', encoding='latin-1')

# %%
df = df.rename(columns={df.columns[0]: 'text'})
df
# Out:
#                                                  text
# 0   2. Samsung Galaxy Watch 6  AMOLED display, he...
# 1   3. Fitbit Versa 4  lightweight design with 24...
# 2   4. Garmin Venu 2  multi-sport tracking, stres...
# 3   5. Amazfit GTR 4  durable smartwatch with lon...
# 4   6. Huawei Watch GT 4  sleek design, accurate ...
# 5   7. Noise ColorFit Pro 4  affordable smartwatc...
# 6   8. Boat Wave Call  Bluetooth calling smartwat...
# 7   9. Fossil Gen 6  WearOS powered with heart se...
# 8   10. OnePlus Watch 2  smart notifications, fit...
# 9   11. Redmi Watch 3 Active  stylish and afforda...
# 10  12. Realme Watch 3 Pro  GPS, heart rate, and ...
# 11  13. Honor Watch GS 3  elegant design with hea...
# 12  14. Fire-Boltt Ninja Call  budget smartwatch ...
# 13  15. TicWatch Pro 5  dual display, extended ba...
# 14  16. Garmin Instinct 2  rugged outdoor smartwa...
# 15  17. Fitbit Inspire 3  compact fitness tracker...
# ...

# %%
df = pd.DataFrame(df)

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 62.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import nltk

# ✅ Download stopwords if not already done
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# ✅ Step 3: Tokenize + Remove stopwords
def preprocess(text):
    tokens = simple_preprocess(str(text))
    return [w for w in tokens if w not in stop_words]

sentences = [preprocess(line) for line in df['text'] if isinstance(line, str)]
sentences[0]
# Out:
# ['samsung',
#  'galaxy',
#  'watch',
#  'amoled',
#  'display',
#  'heart',
#  'rate',
#  'monitor',
#  'workout',
#  'detection']

# %%
# ✅ Step 4: Train Word2Vec model
model = Word2Vec(
    sentences=sentences,
    vector_size=100,
    window=5,
    min_count=1,
    sg=1,
    workers=8,
    epochs=100
)

# %%
model.wv.most_similar("laptop", topn=5)
# Out:
# [('dell', 0.9949093461036682),
#  ('hp', 0.9944738745689392),
#  ('acer', 0.994232714176178),
#  ('inspiron', 0.9940957427024841),
#  ('intel', 0.9939867258071899)]

# %%
model.wv.most_similar("smartwatch", topn=5)
# Out:
# [('boat', 0.9959115982055664),
#  ('call', 0.9957162141799927),
#  ('wave', 0.995472252368927),
#  ('bluetooth', 0.9953848123550415),
#  ('calling', 0.995071530342102)]
